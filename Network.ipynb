# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
a=pd.read_csv('diabetes.csv')
a
# Out:
#      Unnamed: 0  Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin  \
# 0             0            6      148             72             35        0
# 1             1            1       85             66             29        0
# 2             2            8      183             64              0        0
# 3             3            1       89             66             23       94
# 4             4            0      137             40             35      168
# ..          ...          ...      ...            ...            ...      ...
# 763         763           10      101             76             48      180
# 764         764            2      122             70             27        0
# 765         765            5      121             72             23      112
# 766         766            1      126             60              0        0
# 767         767            1       93             70             31        0
#
#       BMI  DiabetesPedigreeFunction  Age  Outcome
# 0    33.6                     0.627   50        1
# 1    26.6                     0.351   31        0
# 2    23.3                     0.672   32        1
# 3    28.1                     0.167   21        0
# 4    43.1                     2.288   33        1
# ..    ...                       ...  ...      ...
# 763  32.9                     0.171   63        0
# 764  36.8                     0.340   27        0
# 765  26.2                     0.245   30        0
# 766  30.1                     0.349   47        1
# 767  30.4                     0.315   23        0
#
# [768 rows x 10 columns]

# %%
a=a[(a['Glucose']>20) & (a['BloodPressure']>20)& (a['SkinThickness']>10) & (a['Insulin']>40)& (a['BMI']>10)& (a['DiabetesPedigreeFunction']>0.1)]
a
# Out:
#      Unnamed: 0  Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin  \
# 3             3            1       89             66             23       94
# 4             4            0      137             40             35      168
# 6             6            3       78             50             32       88
# 8             8            2      197             70             45      543
# 13           13            1      189             60             23      846
# ..          ...          ...      ...            ...            ...      ...
# 751         751            1      121             78             39       74
# 753         753            0      181             88             44      510
# 755         755            1      128             88             39      110
# 763         763           10      101             76             48      180
# 765         765            5      121             72             23      112
#
#       BMI  DiabetesPedigreeFunction  Age  Outcome
# 3    28.1                     0.167   21        0
# 4    43.1                     2.288   33        1
# 6    31.0                     0.248   26        1
# 8    30.5                     0.158   53        1
# 13   30.1                     0.398   59        1
# ..    ...                       ...  ...      ...
# 751  39.0                     0.261   28        0
# 753  43.3                     0.222   26        1
# 755  36.5                     1.057   37        1
# 763  32.9                     0.171   63        0
# 765  26.2                     0.245   30        0
#
# [366 rows x 10 columns]

# %%
a.reset_index(inplace=True)
a
# Out:
#      index  Unnamed: 0  Pregnancies  Glucose  BloodPressure  SkinThickness  \
# 0        3           3            1       89             66             23
# 1        4           4            0      137             40             35
# 2        6           6            3       78             50             32
# 3        8           8            2      197             70             45
# 4       13          13            1      189             60             23
# ..     ...         ...          ...      ...            ...            ...
# 361    751         751            1      121             78             39
# 362    753         753            0      181             88             44
# 363    755         755            1      128             88             39
# 364    763         763           10      101             76             48
# 365    765         765            5      121             72             23
#
#      Insulin   BMI  DiabetesPedigreeFunction  Age  Outcome
# 0         94  28.1                     0.167   21        0
# 1        168  43.1                     2.288   33        1
# 2         88  31.0                     0.248   26        1
# 3        543  30.5                     0.158   53        1
# 4        846  30.1                     0.398   59        1
# ..       ...   ...                       ...  ...      ...
# 361       74  39.0                     0.261   28        0
# 362      510  43.3                     0.222   26        1
# 363      110  36.5                     1.057   37        1
# 364      180  32.9                     0.171   63        0
# 365      112  26.2                     0.245   30        0
#
# [366 rows x 11 columns]

# %%
data=a.iloc[:,2:10]
data
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              1       89             66             23       94  28.1
# 1              0      137             40             35      168  43.1
# 2              3       78             50             32       88  31.0
# 3              2      197             70             45      543  30.5
# 4              1      189             60             23      846  30.1
# ..           ...      ...            ...            ...      ...   ...
# 361            1      121             78             39       74  39.0
# 362            0      181             88             44      510  43.3
# 363            1      128             88             39      110  36.5
# 364           10      101             76             48      180  32.9
# 365            5      121             72             23      112  26.2
#
#      DiabetesPedigreeFunction  Age
# 0                       0.167   21
# 1                       2.288   33
# 2                       0.248   26
# 3                       0.158   53
# 4                       0.398   59
# ..                        ...  ...
# 361                     0.261   28
# 362                     0.222   26
# 363                     1.057   37
# 364                     0.171   63
# 365                     0.245   30
#
# [366 rows x 8 columns]

# %%
#normalizasyon
from sklearn.preprocessing import MinMaxScaler
sc=MinMaxScaler()

x_scaled = sc.fit_transform(data)
x_scaled
# Out:
# array([[0.05882353, 0.23239437, 0.45      , ..., 0.20245399, 0.0270027 ,
#         0.        ],
#        [0.        , 0.57042254, 0.125     , ..., 0.50920245, 0.98154815,
#         0.2       ],
#        [0.17647059, 0.15492958, 0.25      , ..., 0.26175869, 0.06345635,
#         0.08333333],
#        ...,
#        [0.05882353, 0.50704225, 0.725     , ..., 0.37423313, 0.42754275,
#         0.26666667],
#        [0.58823529, 0.31690141, 0.575     , ..., 0.3006135 , 0.02880288,
#         0.7       ],
#        [0.29411765, 0.45774648, 0.525     , ..., 0.16359918, 0.06210621,
#         0.15      ]])

# %%
labels=a['Outcome']
labels
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 361    0
# 362    1
# 363    1
# 364    0
# 365    0
# Name: Outcome, Length: 366, dtype: int64

# %%
X_train, X_test, y_train, y_test = train_test_split(x_scaled, labels, test_size=0.3, random_state=42)

# %%
import random;
class Network:

    def __init__(self) -> None:
        np.random.normal()
        self.w111 = np.random.normal()
        self.w112 = np.random.normal() 
        self.w113 = np.random.normal() 
        self.w114 = np.random.normal() 
        self.w115 = np.random.normal() 
        self.w116 = np.random.normal() 
        self.w117 = np.random.normal() 
        self.w118 = np.random.normal() 
        self.b11 = np.random.normal() 


        self.w121 = np.random.normal() 
        self.w122 = np.random.normal() 
        self.w123 = np.random.normal() 
        self.w124 = np.random.normal() 
        self.w125 = np.random.normal() 
        self.w126 = np.random.normal() 
        self.w127 = np.random.normal() 
        self.w128 = np.random.normal() 
        self.b12 = np.random.normal() 

        self.w131 = np.random.normal() 
        self.w132 = np.random.normal() 
        self.w133 = np.random.normal() 
        self.w134 = np.random.normal() 
        self.w135 = np.random.normal() 
        self.w136 = np.random.normal() 
        self.w137 =np.random.normal() 
        self.w138 = np.random.normal() 
        self.b13 = np.random.normal() 


        self.w211 = np.random.normal() 
        self.w212 = np.random.normal() 
        self.w213 = np.random.normal() 
        self.b21 = np.random.normal() 

        self.w311 = np.random.normal() 
        self.b31 = np.random.normal() 

        self.w321 = np.random.normal() 
        self.b32 = np.random.normal() 

        self.w411 = np.random.normal() 
        self.w412 = np.random.normal() 
        self.b41 = np.random.normal() 

    
    def predict(self , data):


        h1 = self.sigmoid((self.w111 * data[0]) + (self.w112 * data[1])
                            +(self.w113 * data[2]) + (self.w114 * data[3])
                            +(self.w115 * data[4]) + (self.w116 * data[5])
                            +(self.w117 * data[6])+ (self.w118 * data[7]) 
                            +(self.b11))
        

        
        # h2 nöronunun değeri
        h2 = self.sigmoid((self.w121 * data[0]) + (self.w122 * data[1])
                            +(self.w123 * data[2]) + (self.w124 * data[3])
                            +(self.w125 * data[4]) + (self.w126 * data[5])
                            +(self.w127 * data[6])+ (self.w128 * data[7]) 
                            +(self.b12)
                        )
        


        
        h3 = self.sigmoid((self.w131 * data[0]) + (self.w132 * data[1])
                            +(self.w133 * data[2]) + (self.w134 * data[3])
                            +(self.w135 * data[4]) + (self.w136 * data[5])
                            +(self.w137 * data[6])+ (self.w138 * data[7]) 
                            +(self.b13)
                        )
        
 

        
        # Tahmin değeri 01 nöronun değeri
        h4 = self.sigmoid((self.w211 * h1 ) + (self.w212 * h2 ) + (self.w213 * h3) + (self.b21))

    



        h5 = self.sigmoid((self.w311 * h4) + (self.b31))

        h6 = self.sigmoid((self.w321 * h4) + (self.b32))

        o1 = self.sigmoid((self.w411 * h5) + (self.w412 * h6) + (self.b41));


        return o1 
    
    def train(self , data , labels, epochs, learning_rate):

        for epoch in range(epochs):

            for x, y in zip(data , labels):
                
                h1 = self.sigmoid((self.w111 * x[0]) + (self.w112 * x[1])
                            +(self.w113 * x[2]) + (self.w114 * x[3])
                            +(self.w115 * x[4]) + (self.w116 * x[5])
                            +(self.w117 * x[6])+ (self.w118 * x[7]) 
                            +(self.b11)
                         )


        
                # h2 nöronunun değeri
                h2 = self.sigmoid((self.w121 * x[0]) + (self.w122 * x[1])
                                    +(self.w123 * x[2]) + (self.w124 * x[3])
                                    +(self.w125 * x[4]) + (self.w126 * x[5])
                                    +(self.w127 * x[6])+ (self.w128 * x[7]) 
                                    +(self.b12)
                                )
                

                
                h3 = self.sigmoid((self.w131 * x[0]) + (self.w132 * x[1])
                                    +(self.w133 * x[2]) + (self.w134 * x[3])
                                    +(self.w135 * x[4]) + (self.w136 * x[5])
                                    +(self.w137 * x[6])+ (self.w138 * x[7]) 
                                    +(self.b13)
                                )

                
                # Tahmin değeri 01 nöronun değeri
                h4 = self.sigmoid((self.w211 * h1 ) + (self.w212 * h2 ) + (self.w213 * h3) + (self.b21))



                h5 = self.sigmoid((self.w311 * h4) + (self.b31))

   

                h6 = self.sigmoid((self.w321 * h4) + (self.b32))

                o1 = self.sigmoid((self.w411 * h5) + (self.w412 * h6) + (self.b41));




     
                error = y - o1;
            
    
                o1_error_measure = self.sigmoid_der(o1) * error;

        

                h6_error_measure = self.sigmoid_der(h6) * (o1_error_measure * self.w412);



                h5_error_measure = self.sigmoid_der(h5) * (o1_error_measure * self.w411);

      

                h4_error_measure = self.sigmoid_der(h4) * ((h6_error_measure * self.w321) + (h5_error_measure * self.w311))

       

                h3_error_measure = self.sigmoid_der(h3) * (h4_error_measure * self.w213);

     

                h2_error_measure = self.sigmoid_der(h2) * (h4_error_measure * self.w212);

        

                h1_error_measure = self.sigmoid_der(h1) * (h4_error_measure * self.w211);

          
                

     
    

                # Wxyz += dWxyz
                
                
                self.w411 += learning_rate * o1_error_measure * h5;
                self.w412 += learning_rate * o1_error_measure * h6;
 

                self.w311 += learning_rate * h5_error_measure * h4;
                self.w321 += learning_rate * h6_error_measure * h4;


                self.w211 += learning_rate * h4_error_measure * h1;
                self.w212 += learning_rate * h4_error_measure * h2;
                self.w213 += learning_rate * h4_error_measure * h3;


               
                self.w111 += learning_rate * h1_error_measure * x[0];
                self.w112 += learning_rate * h1_error_measure * x[1];
                self.w113 += learning_rate * h1_error_measure * x[2];
                self.w114 += learning_rate * h1_error_measure * x[3];
                self.w115 += learning_rate * h1_error_measure * x[4];
                self.w116 += learning_rate * h1_error_measure * x[5];
                self.w117 += learning_rate * h1_error_measure * x[6];
                self.w118 += learning_rate * h1_error_measure * x[7];
                #-
                self.w121 += learning_rate * h2_error_measure * x[0];
                self.w122 += learning_rate * h2_error_measure * x[1];
                self.w123 += learning_rate * h2_error_measure * x[2];
                self.w124 += learning_rate * h2_error_measure * x[3];
                self.w125 += learning_rate * h2_error_measure * x[4];
                self.w126 += learning_rate * h2_error_measure * x[5];
                self.w127 += learning_rate * h2_error_measure * x[6];
                self.w128 += learning_rate * h2_error_measure * x[7];
                #-
                self.w131 += learning_rate * h3_error_measure * x[0];
                self.w132 += learning_rate * h3_error_measure * x[1];
                self.w133 += learning_rate * h3_error_measure * x[2];
                self.w134 += learning_rate * h3_error_measure * x[3];
                self.w135 += learning_rate * h3_error_measure * x[4];
                self.w136 += learning_rate * h3_error_measure * x[5];
                self.w137 += learning_rate * h3_error_measure * x[6];
                self.w138 += learning_rate * h3_error_measure * x[7];
        

                self.b41 += learning_rate * o1_error_measure;
                self.b31 += learning_rate * h5_error_measure;
                self.b32 += learning_rate * h6_error_measure;
                self.b21 += learning_rate * h4_error_measure;
                self.b11 += learning_rate * h1_error_measure;
                self.b12 += learning_rate * h2_error_measure;
                self.b13 += learning_rate * h3_error_measure;


        predictions = np.apply_along_axis(self.predict ,1, data)
        loss = self.mse_loss(labels , predictions)
        print("Devir %d loss: %.7f" % (epoch, loss))
    
    
    def sigmoid(self , x):
        return (1/(1+np.exp(-x)))   
    
    def sigmoid_der(self , x):
        return x * (1 - x)
    
    def mse_loss(self , y_real , y_prediction):
        return ((y_real - y_prediction) ** 2).mean()

# %%
myNetwork = Network();

# %%
a = myNetwork.predict(X_test);
a
# Out:
# array([0.65607709, 0.65652279, 0.65635886, 0.65692698, 0.65656696,
#        0.65667692, 0.65666905, 0.656531  ])

# %%
myNetwork.train(X_train, y_train, 10000, 0.05);
# Out:
# Devir 9999 loss: 0.0743181

# %%
for x, y in zip(X_test , y_test):
    value = myNetwork.predict(x);
    print("Predict -> {} Gerçek Değer -> {}".format(value, y));
# Out:
# Predict -> 6.361812797637326e-05 Gerçek Değer -> 1
# Predict -> 5.758376527331697e-05 Gerçek Değer -> 0
# Predict -> 3.9795587517296784e-05 Gerçek Değer -> 0
# Predict -> 0.00035868830349838714 Gerçek Değer -> 0
# Predict -> 5.350269193955227e-05 Gerçek Değer -> 0
# Predict -> 4.0575094820683135e-05 Gerçek Değer -> 0
# Predict -> 3.9723564458465035e-05 Gerçek Değer -> 0
# Predict -> 0.8965442815487975 Gerçek Değer -> 0
# Predict -> 0.892119593878654 Gerçek Değer -> 0
# Predict -> 0.8914383428823915 Gerçek Değer -> 1
# Predict -> 4.8811919619333094e-05 Gerçek Değer -> 1
# Predict -> 3.9712178987088824e-05 Gerçek Değer -> 0
# Predict -> 0.8015781352910162 Gerçek Değer -> 0
# Predict -> 0.897280321649162 Gerçek Değer -> 1
# Predict -> 4.1327206480331686e-05 Gerçek Değer -> 0
# Predict -> 0.8919633613335883 Gerçek Değer -> 1
# Predict -> 3.996565233512219e-05 Gerçek Değer -> 0
# Predict -> 4.015499251157066e-05 Gerçek Değer -> 0
# Predict -> 4.2404184971302885e-05 Gerçek Değer -> 0
# Predict -> 0.8972656237737792 Gerçek Değer -> 0
# Predict -> 5.7733001795999457e-05 Gerçek Değer -> 0
# Predict -> 5.438839613961725e-05 Gerçek Değer -> 0
# Predict -> 0.0007665880541238405 Gerçek Değer -> 1
# Predict -> 4.933978136163775e-05 Gerçek Değer -> 0
# Predict -> 3.9733509174855925e-05 Gerçek Değer -> 0
# Predict -> 0.00010242378431355116 Gerçek Değer -> 1
# Predict -> 4.134595545069668e-05 Gerçek Değer -> 0
# Predict -> 0.8972817397417859 Gerçek Değer -> 1
# Predict -> 0.8879342824719881 Gerçek Değer -> 1
# Predict -> 0.8956797127424482 Gerçek Değer -> 1
# Predict -> 4.723171839521769e-05 Gerçek Değer -> 0
# Predict -> 4.535686161183574e-05 Gerçek Değer -> 0
# Predict -> 5.852107092629627e-05 Gerçek Değer -> 0
# Predict -> 4.014564563823693e-05 Gerçek Değer -> 0
# Predict -> 0.0001014686422415921 Gerçek Değer -> 0
# Predict -> 4.0357453528421165e-05 Gerçek Değer -> 0
# Predict -> 0.00021885012280376895 Gerçek Değer -> 0
# Predict -> 0.8972817195339573 Gerçek Değer -> 0
# Predict -> 0.8966354128263464 Gerçek Değer -> 0
# Predict -> 0.000614702543844113 Gerçek Değer -> 1
# Predict -> 4.44881705568581e-05 Gerçek Değer -> 0
# Predict -> 0.8972338018901165 Gerçek Değer -> 1
# Predict -> 4.003986742515756e-05 Gerçek Değer -> 0
# Predict -> 7.331177310843689e-05 Gerçek Değer -> 0
# Predict -> 4.4654379915758754e-05 Gerçek Değer -> 0
# Predict -> 4.19123924217384e-05 Gerçek Değer -> 0
# Predict -> 3.9746873467014594e-05 Gerçek Değer -> 0
# Predict -> 4.0103574129170474e-05 Gerçek Değer -> 0
# Predict -> 0.897281255188457 Gerçek Değer -> 1
# Predict -> 0.8972810633268297 Gerçek Değer -> 1
# Predict -> 4.544597669106857e-05 Gerçek Değer -> 1
# Predict -> 0.0001165327541641855 Gerçek Değer -> 0
# Predict -> 0.8969886119202845 Gerçek Değer -> 0
# Predict -> 4.418425279748837e-05 Gerçek Değer -> 0
# Predict -> 0.007247136646860334 Gerçek Değer -> 0
# Predict -> 4.1382172181032396e-05 Gerçek Değer -> 0
# Predict -> 6.197154533698608e-05 Gerçek Değer -> 1
# Predict -> 0.8972817585249371 Gerçek Değer -> 1
# Predict -> 0.8972816668059542 Gerçek Değer -> 1
# Predict -> 0.8972817508785345 Gerçek Değer -> 1
# Predict -> 4.018923857288732e-05 Gerçek Değer -> 0
# Predict -> 3.973131375600611e-05 Gerçek Değer -> 0
# Predict -> 5.8359052411410926e-05 Gerçek Değer -> 1
# Predict -> 0.8972817351715761 Gerçek Değer -> 1
# Predict -> 4.067927781933661e-05 Gerçek Değer -> 0
# Predict -> 4.753367889472529e-05 Gerçek Değer -> 0
# Predict -> 4.219131424072213e-05 Gerçek Değer -> 0
# Predict -> 3.971681726506972e-05 Gerçek Değer -> 0
# Predict -> 5.8077983264553586e-05 Gerçek Değer -> 1
# Predict -> 5.4441103143262434e-05 Gerçek Değer -> 1
# Predict -> 5.659082124145933e-05 Gerçek Değer -> 1
# Predict -> 4.528382603121024e-05 Gerçek Değer -> 0
# Predict -> 0.8972781826754426 Gerçek Değer -> 1
# Predict -> 6.345930793641454e-05 Gerçek Değer -> 0
# Predict -> 4.139318535656028e-05 Gerçek Değer -> 0
# Predict -> 0.002214078776120768 Gerçek Değer -> 0
# Predict -> 0.005714584107077124 Gerçek Değer -> 0
# Predict -> 6.559874789081046e-05 Gerçek Değer -> 0
# Predict -> 0.8971745731862406 Gerçek Değer -> 1
# Predict -> 4.226800300904758e-05 Gerçek Değer -> 0
# Predict -> 4.0333655785563787e-05 Gerçek Değer -> 0
# Predict -> 4.122357259788516e-05 Gerçek Değer -> 0
# Predict -> 4.0944377693824695e-05 Gerçek Değer -> 0
# Predict -> 0.8972814660152202 Gerçek Değer -> 0
# Predict -> 3.985341963453604e-05 Gerçek Değer -> 0
# Predict -> 4.0146348039254546e-05 Gerçek Değer -> 0
# Predict -> 4.288761141845918e-05 Gerçek Değer -> 0
# Predict -> 0.8972359290259649 Gerçek Değer -> 1
# Predict -> 3.974070908000879e-05 Gerçek Değer -> 0
# Predict -> 3.996261850866549e-05 Gerçek Değer -> 0
# Predict -> 0.8972817370227384 Gerçek Değer -> 0
# Predict -> 4.221825751260407e-05 Gerçek Değer -> 0
# Predict -> 3.977662059542779e-05 Gerçek Değer -> 0
# Predict -> 0.8972817584809925 Gerçek Değer -> 1
# Predict -> 0.0011977573879121983 Gerçek Değer -> 1
# Predict -> 0.0007318889273570515 Gerçek Değer -> 0
# Predict -> 7.434300319188609e-05 Gerçek Değer -> 0
# Predict -> 3.971737583017595e-05 Gerçek Değer -> 1
# Predict -> 4.0719724768018625e-05 Gerçek Değer -> 1
# Predict -> 0.8969570851646921 Gerçek Değer -> 0
# Predict -> 0.008416096407354866 Gerçek Değer -> 0
# Predict -> 0.8972815798659758 Gerçek Değer -> 0
# Predict -> 0.897277685996939 Gerçek Değer -> 0
# Predict -> 0.8972805110918995 Gerçek Değer -> 1
# Predict -> 0.894811369522042 Gerçek Değer -> 1
# Predict -> 3.975353664185241e-05 Gerçek Değer -> 0
# Predict -> 5.152213812680593e-05 Gerçek Değer -> 1
# Predict -> 0.889465709031495 Gerçek Değer -> 0
# Predict -> 0.00023164856786957706 Gerçek Değer -> 0
# Predict -> 6.0538084395973915e-05 Gerçek Değer -> 0

# %%
all_prediction =  [];
for x in X_test:
    if(myNetwork.predict(x) > 0.4):
        all_prediction.append(1)
    else:
        all_prediction.append(0);

# %%
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(y_test, all_prediction)
cm.T
# Out:
# array([[63, 15],
#        [13, 19]], dtype=int64)

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, all_prediction));
# Out:
#               precision    recall  f1-score   support
#
#            0       0.81      0.83      0.82        76
#            1       0.59      0.56      0.58        34
#
#     accuracy                           0.75       110
#    macro avg       0.70      0.69      0.70       110
# weighted avg       0.74      0.75      0.74       110
