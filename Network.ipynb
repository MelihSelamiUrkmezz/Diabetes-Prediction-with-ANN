# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
a=pd.read_csv('diabetes.csv')
a
# Out:
#      Unnamed: 0  Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin  \
# 0             0            6      148             72             35        0
# 1             1            1       85             66             29        0
# 2             2            8      183             64              0        0
# 3             3            1       89             66             23       94
# 4             4            0      137             40             35      168
# ..          ...          ...      ...            ...            ...      ...
# 763         763           10      101             76             48      180
# 764         764            2      122             70             27        0
# 765         765            5      121             72             23      112
# 766         766            1      126             60              0        0
# 767         767            1       93             70             31        0
#
#       BMI  DiabetesPedigreeFunction  Age  Outcome
# 0    33.6                     0.627   50        1
# 1    26.6                     0.351   31        0
# 2    23.3                     0.672   32        1
# 3    28.1                     0.167   21        0
# 4    43.1                     2.288   33        1
# ..    ...                       ...  ...      ...
# 763  32.9                     0.171   63        0
# 764  36.8                     0.340   27        0
# 765  26.2                     0.245   30        0
# 766  30.1                     0.349   47        1
# 767  30.4                     0.315   23        0
#
# [768 rows x 10 columns]

# %%
a=a[(a['Glucose']>20) & (a['BloodPressure']>20)& (a['SkinThickness']>10) & (a['Insulin']>40)& (a['BMI']>10)& (a['DiabetesPedigreeFunction']>0.1)]
a
# Out:
#      Unnamed: 0  Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin  \
# 3             3            1       89             66             23       94
# 4             4            0      137             40             35      168
# 6             6            3       78             50             32       88
# 8             8            2      197             70             45      543
# 13           13            1      189             60             23      846
# ..          ...          ...      ...            ...            ...      ...
# 751         751            1      121             78             39       74
# 753         753            0      181             88             44      510
# 755         755            1      128             88             39      110
# 763         763           10      101             76             48      180
# 765         765            5      121             72             23      112
#
#       BMI  DiabetesPedigreeFunction  Age  Outcome
# 3    28.1                     0.167   21        0
# 4    43.1                     2.288   33        1
# 6    31.0                     0.248   26        1
# 8    30.5                     0.158   53        1
# 13   30.1                     0.398   59        1
# ..    ...                       ...  ...      ...
# 751  39.0                     0.261   28        0
# 753  43.3                     0.222   26        1
# 755  36.5                     1.057   37        1
# 763  32.9                     0.171   63        0
# 765  26.2                     0.245   30        0
#
# [366 rows x 10 columns]

# %%
a.reset_index(inplace=True)
a
# Out:
#      index  Unnamed: 0  Pregnancies  Glucose  BloodPressure  SkinThickness  \
# 0        3           3            1       89             66             23
# 1        4           4            0      137             40             35
# 2        6           6            3       78             50             32
# 3        8           8            2      197             70             45
# 4       13          13            1      189             60             23
# ..     ...         ...          ...      ...            ...            ...
# 361    751         751            1      121             78             39
# 362    753         753            0      181             88             44
# 363    755         755            1      128             88             39
# 364    763         763           10      101             76             48
# 365    765         765            5      121             72             23
#
#      Insulin   BMI  DiabetesPedigreeFunction  Age  Outcome
# 0         94  28.1                     0.167   21        0
# 1        168  43.1                     2.288   33        1
# 2         88  31.0                     0.248   26        1
# 3        543  30.5                     0.158   53        1
# 4        846  30.1                     0.398   59        1
# ..       ...   ...                       ...  ...      ...
# 361       74  39.0                     0.261   28        0
# 362      510  43.3                     0.222   26        1
# 363      110  36.5                     1.057   37        1
# 364      180  32.9                     0.171   63        0
# 365      112  26.2                     0.245   30        0
#
# [366 rows x 11 columns]

# %%
data=a.iloc[:,2:10]
data
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              1       89             66             23       94  28.1
# 1              0      137             40             35      168  43.1
# 2              3       78             50             32       88  31.0
# 3              2      197             70             45      543  30.5
# 4              1      189             60             23      846  30.1
# ..           ...      ...            ...            ...      ...   ...
# 361            1      121             78             39       74  39.0
# 362            0      181             88             44      510  43.3
# 363            1      128             88             39      110  36.5
# 364           10      101             76             48      180  32.9
# 365            5      121             72             23      112  26.2
#
#      DiabetesPedigreeFunction  Age
# 0                       0.167   21
# 1                       2.288   33
# 2                       0.248   26
# 3                       0.158   53
# 4                       0.398   59
# ..                        ...  ...
# 361                     0.261   28
# 362                     0.222   26
# 363                     1.057   37
# 364                     0.171   63
# 365                     0.245   30
#
# [366 rows x 8 columns]

# %%
#normalizasyon
from sklearn.preprocessing import MinMaxScaler
sc=MinMaxScaler()

x_scaled = sc.fit_transform(data)
x_scaled
# Out:
# array([[0.05882353, 0.23239437, 0.45      , ..., 0.20245399, 0.0270027 ,
#         0.        ],
#        [0.        , 0.57042254, 0.125     , ..., 0.50920245, 0.98154815,
#         0.2       ],
#        [0.17647059, 0.15492958, 0.25      , ..., 0.26175869, 0.06345635,
#         0.08333333],
#        ...,
#        [0.05882353, 0.50704225, 0.725     , ..., 0.37423313, 0.42754275,
#         0.26666667],
#        [0.58823529, 0.31690141, 0.575     , ..., 0.3006135 , 0.02880288,
#         0.7       ],
#        [0.29411765, 0.45774648, 0.525     , ..., 0.16359918, 0.06210621,
#         0.15      ]])

# %%
labels=a['Outcome']
labels
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 361    0
# 362    1
# 363    1
# 364    0
# 365    0
# Name: Outcome, Length: 366, dtype: int64

# %%
X_train, X_test, y_train, y_test = train_test_split(x_scaled, labels, test_size=0.3, random_state=42)

# %%
import random;
class Network:

    def __init__(self) -> None:
        np.random.normal()
        self.w111 = np.random.normal()
        self.w112 = np.random.normal() 
        self.w113 = np.random.normal() 
        self.w114 = np.random.normal() 
        self.w115 = np.random.normal() 
        self.w116 = np.random.normal() 
        self.w117 = np.random.normal() 
        self.w118 = np.random.normal() 
        self.b11 = np.random.normal() 


        self.w121 = np.random.normal() 
        self.w122 = np.random.normal() 
        self.w123 = np.random.normal() 
        self.w124 = np.random.normal() 
        self.w125 = np.random.normal() 
        self.w126 = np.random.normal() 
        self.w127 = np.random.normal() 
        self.w128 = np.random.normal() 
        self.b12 = np.random.normal() 

        self.w131 = np.random.normal() 
        self.w132 = np.random.normal() 
        self.w133 = np.random.normal() 
        self.w134 = np.random.normal() 
        self.w135 = np.random.normal() 
        self.w136 = np.random.normal() 
        self.w137 =np.random.normal() 
        self.w138 = np.random.normal() 
        self.b13 = np.random.normal() 


        self.w211 = np.random.normal() 
        self.w212 = np.random.normal() 
        self.w213 = np.random.normal() 
        self.b21 = np.random.normal() 

        self.w311 = np.random.normal() 
        self.b31 = np.random.normal() 

        self.w321 = np.random.normal() 
        self.b32 = np.random.normal() 

        self.w411 = np.random.normal() 
        self.w412 = np.random.normal() 
        self.b41 = np.random.normal() 

    
    def predict(self , data):


        h1 = self.sigmoid((self.w111 * data[0]) + (self.w112 * data[1])
                            +(self.w113 * data[2]) + (self.w114 * data[3])
                            +(self.w115 * data[4]) + (self.w116 * data[5])
                            +(self.w117 * data[6])+ (self.w118 * data[7]) 
                            +(self.b11))
        

        
        # h2 nöronunun değeri
        h2 = self.sigmoid((self.w121 * data[0]) + (self.w122 * data[1])
                            +(self.w123 * data[2]) + (self.w124 * data[3])
                            +(self.w125 * data[4]) + (self.w126 * data[5])
                            +(self.w127 * data[6])+ (self.w128 * data[7]) 
                            +(self.b12)
                        )
        


        
        h3 = self.sigmoid((self.w131 * data[0]) + (self.w132 * data[1])
                            +(self.w133 * data[2]) + (self.w134 * data[3])
                            +(self.w135 * data[4]) + (self.w136 * data[5])
                            +(self.w137 * data[6])+ (self.w138 * data[7]) 
                            +(self.b13)
                        )
        
 

        
        # Tahmin değeri 01 nöronun değeri
        h4 = self.sigmoid((self.w211 * h1 ) + (self.w212 * h2 ) + (self.w213 * h3) + (self.b21))

    



        h5 = self.sigmoid((self.w311 * h4) + (self.b31))

        h6 = self.sigmoid((self.w321 * h4) + (self.b32))

        o1 = self.sigmoid((self.w411 * h5) + (self.w412 * h6) + (self.b41));


        return o1 
    
    def train(self , data , labels, epochs, learning_rate):

        for epoch in range(epochs):

            for x, y in zip(data , labels):
                
                h1 = self.sigmoid((self.w111 * x[0]) + (self.w112 * x[1])
                            +(self.w113 * x[2]) + (self.w114 * x[3])
                            +(self.w115 * x[4]) + (self.w116 * x[5])
                            +(self.w117 * x[6])+ (self.w118 * x[7]) 
                            +(self.b11)
                         )


        
                # h2 nöronunun değeri
                h2 = self.sigmoid((self.w121 * x[0]) + (self.w122 * x[1])
                                    +(self.w123 * x[2]) + (self.w124 * x[3])
                                    +(self.w125 * x[4]) + (self.w126 * x[5])
                                    +(self.w127 * x[6])+ (self.w128 * x[7]) 
                                    +(self.b12)
                                )
                

                
                h3 = self.sigmoid((self.w131 * x[0]) + (self.w132 * x[1])
                                    +(self.w133 * x[2]) + (self.w134 * x[3])
                                    +(self.w135 * x[4]) + (self.w136 * x[5])
                                    +(self.w137 * x[6])+ (self.w138 * x[7]) 
                                    +(self.b13)
                                )

                
                # Tahmin değeri 01 nöronun değeri
                h4 = self.sigmoid((self.w211 * h1 ) + (self.w212 * h2 ) + (self.w213 * h3) + (self.b21))



                h5 = self.sigmoid((self.w311 * h4) + (self.b31))

   

                h6 = self.sigmoid((self.w321 * h4) + (self.b32))

                o1 = self.sigmoid((self.w411 * h5) + (self.w412 * h6) + (self.b41));




     
                error = y - o1;
            
    
                o1_error_measure = self.sigmoid_der(o1) * error;

        

                h6_error_measure = self.sigmoid_der(h6) * (o1_error_measure * self.w412);



                h5_error_measure = self.sigmoid_der(h5) * (o1_error_measure * self.w411);

      

                h4_error_measure = self.sigmoid_der(h4) * ((h6_error_measure * self.w321) + (h5_error_measure * self.w311))

       

                h3_error_measure = self.sigmoid_der(h3) * (h4_error_measure * self.w213);

     

                h2_error_measure = self.sigmoid_der(h2) * (h4_error_measure * self.w212);

        

                h1_error_measure = self.sigmoid_der(h1) * (h4_error_measure * self.w211);

          
                

     
    

                # Wxyz += dWxyz
                
                
                self.w411 += learning_rate * o1_error_measure * h5;
                self.w412 += learning_rate * o1_error_measure * h6;
 

                self.w311 += learning_rate * h5_error_measure * h4;
                self.w321 += learning_rate * h6_error_measure * h4;


                self.w211 += learning_rate * h4_error_measure * h1;
                self.w212 += learning_rate * h4_error_measure * h2;
                self.w213 += learning_rate * h4_error_measure * h3;


               
                self.w111 += learning_rate * h1_error_measure * x[0];
                self.w112 += learning_rate * h1_error_measure * x[1];
                self.w113 += learning_rate * h1_error_measure * x[2];
                self.w114 += learning_rate * h1_error_measure * x[3];
                self.w115 += learning_rate * h1_error_measure * x[4];
                self.w116 += learning_rate * h1_error_measure * x[5];
                self.w117 += learning_rate * h1_error_measure * x[6];
                self.w118 += learning_rate * h1_error_measure * x[7];
                #-
                self.w121 += learning_rate * h2_error_measure * x[0];
                self.w122 += learning_rate * h2_error_measure * x[1];
                self.w123 += learning_rate * h2_error_measure * x[2];
                self.w124 += learning_rate * h2_error_measure * x[3];
                self.w125 += learning_rate * h2_error_measure * x[4];
                self.w126 += learning_rate * h2_error_measure * x[5];
                self.w127 += learning_rate * h2_error_measure * x[6];
                self.w128 += learning_rate * h2_error_measure * x[7];
                #-
                self.w131 += learning_rate * h3_error_measure * x[0];
                self.w132 += learning_rate * h3_error_measure * x[1];
                self.w133 += learning_rate * h3_error_measure * x[2];
                self.w134 += learning_rate * h3_error_measure * x[3];
                self.w135 += learning_rate * h3_error_measure * x[4];
                self.w136 += learning_rate * h3_error_measure * x[5];
                self.w137 += learning_rate * h3_error_measure * x[6];
                self.w138 += learning_rate * h3_error_measure * x[7];
        

                self.b41 += learning_rate * o1_error_measure;
                self.b31 += learning_rate * h5_error_measure;
                self.b32 += learning_rate * h6_error_measure;
                self.b21 += learning_rate * h4_error_measure;
                self.b11 += learning_rate * h1_error_measure;
                self.b12 += learning_rate * h2_error_measure;
                self.b13 += learning_rate * h3_error_measure;


        predictions = np.apply_along_axis(self.predict ,1, data)
        loss = self.mse_loss(labels , predictions)
        print("Devir %d loss: %.7f" % (epoch, loss))
    
    
    def sigmoid(self , x):
        return (1/(1+np.exp(-x)))   
    
    def sigmoid_der(self , x):
        return x * (1 - x)
    
    def mse_loss(self , y_real , y_prediction):
        return ((y_real - y_prediction) ** 2).mean()

# %%
myNetwork = Network();
# Out:
# 0.12
# 0.12

# %%
a = myNetwork.predict(X_test);
a
# Out:
# h3 [0.61454805 0.8173538  0.86199981 0.73049646 0.61433357 0.75649497
#  0.64119684 0.57207774]
# h4 [0.83930363 0.87314492 0.8776447  0.85886389 0.83407595 0.86237215
#  0.84089759 0.83022682]
# array([0.8695278 , 0.87008763, 0.8701617 , 0.86985196, 0.8694409 ,
#        0.86990994, 0.86955428, 0.86937684])

# %%
myNetwork.train(X_train, y_train, 10000, 0.05);
# Out:
# h3 0.7186646870684533
# h4 0.814642910131433
# h3 0.7566782744038626
# h4 0.8598564966017256
# h3 0.4863941782124437
# h4 0.3845423721468494
# h3 0.7912776608962407
# h4 0.8434695649114183
# h3 0.5231641108831288
# h4 0.47913225625365735
# h3 0.48195988721944516
# h4 0.32596711702891523
# h3 0.40771753858427695
# h4 0.23156515343214157
# h3 0.6161036066962157
# h3 0.40389051554878613
# h4 0.18196182894874155
# h3 0.5132915132128201
# h4 0.4892412556693995
# h3 0.5312866220535806
# h4 0.46501419718760767
# h3 0.5540893386026002
# h4 0.5262509589259892
# h3 0.42739690222461396
# h4 0.25924667603725604
# h3 0.5147616419872805
# h4 0.3971591643081692
# h3 0.6640457182890984
# h4 0.757774470117255
# Devir 999 loss: 0.1394325

# %%
for x, y in zip(X_test , y_test):
    value = myNetwork.predict(x);
    print("Predict -> {} Gerçek Değer -> {}".format(value, y));
# Out:
# h3 0.532016048847171
# h4 0.49979950045953725
# Predict -> 0.4172626699075897 Gerçek Değer -> 1
# h3 0.436275687440655
# h4 0.26830507321038305
# Predict -> 0.1376075320802453 Gerçek Değer -> 0
# h3 0.3438176884699896
# h4 0.15069368226245358
# Predict -> 0.079265631100175 Gerçek Değer -> 0
# h3 0.46474474999050425
# h4 0.33659216226889704
# Predict -> 0.19449839119868848 Gerçek Değer -> 0
# h3 0.4167844625155643
# h4 0.23258797815434284
# Predict -> 0.11542844262980895 Gerçek Değer -> 0
# h3 0.5246508279868637
# h4 0.4181947353538774
# Predict -> 0.2917185193733108 Gerçek Değer -> 0
# h3 0.35392126452294015
# h4 0.18503409763970086
# Predict -> 0.09230293512767976 Gerçek Değer -> 0
# h3 0.5859908763693343
# h4 0.5578994701011422
# Predict -> 0.5138072984026761 Gerçek Değer -> 0
# h3 0.6618601179891581
# h4 0.7455811766879255
# Predict -> 0.7626840166590366 Gerçek Değer -> 0
# h3 0.4621213163689836
# h4 0.3358531323235935
# Predict -> 0.19376804706334114 Gerçek Değer -> 1
# h3 0.45837368354871005
# h4 0.3214496121543936
# Predict -> 0.18005869670201866 Gerçek Değer -> 1
# h3 0.28434003736653346
# h4 0.1271407930161139
# Predict -> 0.07175948527244831 Gerçek Değer -> 0
# h3 0.6572335930710675
# h4 0.7402385618979976
# Predict -> 0.75770653436161 Gerçek Değer -> 0
# h3 0.6416590810087212
# h4 0.727651817437086
# Predict -> 0.7454864069414667 Gerçek Değer -> 1
# h3 0.46655190838331084
# h4 0.29541110197051895
# Predict -> 0.1577269409703277 Gerçek Değer -> 0
# h3 0.5361588087621518
# h4 0.4330882717790725
# Predict -> 0.31287562518426637 Gerçek Değer -> 1
# h3 0.3599555266802485
# h4 0.17581725228547604
# Predict -> 0.08853492985228996 Gerçek Değer -> 0
# h3 0.40150873791631647
# h4 0.21546302098147585
# Predict -> 0.10633480441478357 Gerçek Değer -> 0
# h3 0.39940468515046956
# h4 0.25074567953662846
# Predict -> 0.12612878340681918 Gerçek Değer -> 0
# h3 0.8800520033745483
# h4 0.9140971344727765
# Predict -> 0.867642294037051 Gerçek Değer -> 0
# h3 0.6115035471261441
# h4 0.6058653795265827
# Predict -> 0.5903425656733807 Gerçek Değer -> 0
# h3 0.4418208538580887
# h4 0.31649116782003567
# Predict -> 0.17556690261779972 Gerçek Değer -> 0
# h3 0.515760419016897
# h4 0.3996870629791015
# Predict -> 0.2668188404472637 Gerçek Değer -> 1
# h3 0.4099729224013531
# h4 0.24876350198686342
# Predict -> 0.12490467020635568 Gerçek Değer -> 0
# h3 0.35439057607700225
# h4 0.16837924398722307
# Predict -> 0.08564307207144523 Gerçek Değer -> 0
# h3 0.47997141897196466
# h4 0.38009742740053054
# Predict -> 0.24225013484008703 Gerçek Değer -> 1
# h3 0.42272334813128626
# h4 0.2458818721377383
# Predict -> 0.1231501137936474 Gerçek Değer -> 0
# h3 0.6463561702651696
# h4 0.719586652588476
# Predict -> 0.7372849816351279 Gerçek Değer -> 1
# h3 0.6955931816421741
# h4 0.7386105002656078
# Predict -> 0.756165129790971 Gerçek Değer -> 1
# h3 0.7419401046504899
# h4 0.8347770724893749
# Predict -> 0.8292317481830888 Gerçek Değer -> 1
# h3 0.44739097120175886
# h4 0.34438067484058493
# Predict -> 0.20235747800733106 Gerçek Değer -> 0
# h3 0.7648362393572794
# h4 0.8367076104467632
# Predict -> 0.8303666293140184 Gerçek Değer -> 0
# h3 0.49978390599353517
# h4 0.4133028615640605
# Predict -> 0.28498286190417377 Gerçek Değer -> 0
# h3 0.43552113379235075
# h4 0.2538997400826517
# Predict -> 0.12810590109309883 Gerçek Değer -> 0
# h3 0.5696551731751662
# h4 0.5209887306665463
# Predict -> 0.4524217808964596 Gerçek Değer -> 0
# h3 0.5041670609136778
# h4 0.3728218592685815
# Predict -> 0.2336078189276992 Gerçek Değer -> 0
# h3 0.5712811486188611
# h4 0.6020854710249373
# Predict -> 0.5845417316018309 Gerçek Değer -> 0
# h3 0.6842563330114105
# h4 0.7998835029649272
# Predict -> 0.8066571757413917 Gerçek Değer -> 0
# h3 0.5465021128650085
# h4 0.4827859254477744
# Predict -> 0.3894862651517145 Gerçek Değer -> 0
# h3 0.5916826825149755
# h4 0.6795715643360541
# Predict -> 0.692181837690399 Gerçek Değer -> 1
# h3 0.4749306509341899
# h4 0.33656477713539756
# Predict -> 0.19447128056007332 Gerçek Değer -> 0
# h3 0.5571732418112542
# h4 0.5823748230423182
# Predict -> 0.5535807912420755 Gerçek Değer -> 1
# h3 0.566297058774893
# h4 0.43945243035828635
# Predict -> 0.3222004889231001 Gerçek Değer -> 0
# h3 0.43607033391708155
# h4 0.29275254413979845
# Predict -> 0.15561724737752936 Gerçek Değer -> 0
# h3 0.6132650028624069
# h4 0.6514872629670291
# Predict -> 0.6561173442454317 Gerçek Değer -> 0
# h3 0.383913954910702
# h4 0.17676650542151437
# Predict -> 0.08891340803171532 Gerçek Değer -> 0
# h3 0.5318524977547706
# h4 0.5481265017327573
# Predict -> 0.4976452931784957 Gerçek Değer -> 0
# h3 0.391087018710646
# h4 0.18819371743859628
# Predict -> 0.09364353565500567 Gerçek Değer -> 0
# h3 0.6484749912855412
# h4 0.7184471221549874
# Predict -> 0.7361025047564729 Gerçek Değer -> 1
# h3 0.7049189845032132
# h4 0.8119785165742297
# Predict -> 0.8149412930090391 Gerçek Değer -> 1
# h3 0.574895109156966
# h4 0.5474254665675807
# Predict -> 0.4964818195141135 Gerçek Değer -> 1
# h3 0.4695937407633251
# h4 0.41772160381104534
# Predict -> 0.2910623323390629 Gerçek Değer -> 0
# h3 0.5953661176198298
# h4 0.6431627917667354
# Predict -> 0.644749718391686 Gerçek Değer -> 0
# h3 0.5177432916913121
# h4 0.4114399711309791
# Predict -> 0.2824465508651285 Gerçek Değer -> 0
# h3 0.4723512138182447
# h4 0.3236273434006115
# Predict -> 0.18206798086178386 Gerçek Değer -> 0
# h3 0.4972634346251932
# h4 0.4335110409937843
# Predict -> 0.3134899652876176 Gerçek Değer -> 0
# h3 0.548713503554644
# h4 0.49252416168321067
# Predict -> 0.4053189200483527 Gerçek Değer -> 1
# h3 0.7569742779096965
# h4 0.8800144373504905
# Predict -> 0.8530542708809309 Gerçek Değer -> 1
# h3 0.6879649311043492
# h4 0.7609755744730184
# Predict -> 0.7763475233471099 Gerçek Değer -> 1
# h3 0.7101658845733533
# h4 0.8048335494147214
# Predict -> 0.8101090550000142 Gerçek Değer -> 1
# h3 0.4630632824725767
# h4 0.24392861219569734
# Predict -> 0.12197749444871267 Gerçek Değer -> 0
# h3 0.5490460550559377
# h4 0.6391540910844282
# Predict -> 0.6391691718413953 Gerçek Değer -> 0
# h3 0.657276204278168
# h4 0.6503626470092182
# Predict -> 0.6545992617681737 Gerçek Değer -> 1
# h3 0.6309722358977083
# h4 0.7228143288151309
# Predict -> 0.7406023735544407 Gerçek Değer -> 1
# h3 0.3677273825821959
# h4 0.18796306861869722
# Predict -> 0.09354480827532205 Gerçek Değer -> 0
# h3 0.48299026131766587
# h4 0.2644544067870478
# Predict -> 0.13499028102474614 Gerçek Değer -> 0
# h3 0.4925514922978943
# h4 0.31976345714613114
# Predict -> 0.1785183111367961 Gerçek Değer -> 0
# h3 0.36611538996137183
# h4 0.1850618217889077
# Predict -> 0.09231458770815473 Gerçek Değer -> 0
# h3 0.4609570201638088
# h4 0.3355965983993393
# Predict -> 0.19351514850410392 Gerçek Değer -> 1
# h3 0.525960367061416
# h4 0.44598794920329343
# Predict -> 0.33194271892480465 Gerçek Değer -> 1
# h3 0.5510002304477909
# h4 0.47816996119644517
# Predict -> 0.38205449737406505 Gerçek Değer -> 1
# h3 0.495815524664217
# h4 0.34262879904679333
# Predict -> 0.20056382252940394 Gerçek Değer -> 0
# h3 0.6198526567315308
# h4 0.7046658270463384
# Predict -> 0.7213320349760968 Gerçek Değer -> 1
# h3 0.4498177487704058
# h4 0.2696405718385663
# Predict -> 0.13852875324446684 Gerçek Değer -> 0
# h3 0.4990176475793905
# h4 0.40165123047766765
# Predict -> 0.2693850799613703 Gerçek Değer -> 0
# h3 0.5787320711156515
# h4 0.5531553830652378
# Predict -> 0.5059763448144377 Gerçek Değer -> 0
# h3 0.4104020761978967
# h4 0.2748622574207681
# Predict -> 0.14219839095790307 Gerçek Değer -> 0
# h3 0.5604655118889763
# h4 0.5848645523592979
# Predict -> 0.5575520663025072 Gerçek Değer -> 0
# h3 0.6496945650040397
# h4 0.7071461972008264
# Predict -> 0.7240548048868762 Gerçek Değer -> 1
# h3 0.490433646501226
# h4 0.42435087529719245
# Predict -> 0.30034722598423913 Gerçek Değer -> 0
# h3 0.39005049963463334
# h4 0.20524359656074556
# Predict -> 0.10133402073728577 Gerçek Değer -> 0
# h3 0.3947362314780608
# h4 0.20494185508906893
# Predict -> 0.10119096426785336 Gerçek Değer -> 0
# h3 0.4028448696451607
# h4 0.3685521232928144
# Predict -> 0.22865893934352322 Gerçek Değer -> 0
# h3 0.6542915411396868
# h4 0.6916208710312
# Predict -> 0.7065435230581727 Gerçek Değer -> 0
# h3 0.37209699692882253
# h4 0.21212487526570292
# Predict -> 0.10466759717497787 Gerçek Değer -> 0
# h3 0.6731172608244339
# h4 0.6471123266313402
# Predict -> 0.6501806165829535 Gerçek Değer -> 0
# h3 0.5500719505600122
# h4 0.46768478277636066
# Predict -> 0.3653770846150163 Gerçek Değer -> 0
# h3 0.6287744160373823
# h4 0.661103824710196
# Predict -> 0.6688691281774116 Gerçek Değer -> 1
# h3 0.36307261502330695
# h4 0.16467318434509903
# Predict -> 0.08424983707859793 Gerçek Değer -> 0
# h3 0.3734628058379696
# h4 0.1609484050077228
# Predict -> 0.08288055730134172 Gerçek Değer -> 0
# h3 0.6704845563686741
# h4 0.7622204317196855
# Predict -> 0.7774092812243397 Gerçek Değer -> 0
# h3 0.41067583764583554
# h4 0.25932388544421664
# Predict -> 0.13159157953260586 Gerçek Değer -> 0
# h3 0.42541620285325904
# h4 0.2565564571724461
# Predict -> 0.1297995245781346 Gerçek Değer -> 0
# h3 0.7754205544731929
# h4 0.8614464959201206
# Predict -> 0.8439482787945652 Gerçek Değer -> 1
# h3 0.5737856491639667
# h4 0.5191033228723981
# Predict -> 0.44927894700440946 Gerçek Değer -> 1
# h3 0.6698132370041637
# h4 0.7222969116449947
# Predict -> 0.7400737441670329 Gerçek Değer -> 0
# h3 0.4845213129936442
# h4 0.37551079326048664
# Predict -> 0.23677115994961637 Gerçek Değer -> 0
# h3 0.6297053146057746
# h4 0.7507947032333324
# Predict -> 0.7674231205081095 Gerçek Değer -> 1
# h3 0.48613236129769566
# h4 0.33336411136045013
# Predict -> 0.1913277684397288 Gerçek Değer -> 1
# h3 0.5592906325797314
# h4 0.5717371069017739
# Predict -> 0.5364438418227798 Gerçek Değer -> 0
# h3 0.4506314196996723
# h4 0.35208475145009516
# Predict -> 0.21042499987016475 Gerçek Değer -> 0
# h3 0.6223416992968497
# h4 0.6614612950335428
# Predict -> 0.6693351520970453 Gerçek Değer -> 0
# h3 0.7502539956139933
# h4 0.8084231691740414
# Predict -> 0.8125586854226112 Gerçek Değer -> 0
# h3 0.6449458291174561
# h4 0.6963621811853605
# Predict -> 0.7120098474667926 Gerçek Değer -> 1
# h3 0.5560415121106963
# h4 0.5163460784646512
# Predict -> 0.44468608805823595 Gerçek Değer -> 1
# h3 0.37959511136920715
# h4 0.19802891648455936
# Predict -> 0.09798343012893651 Gerçek Değer -> 0
# h3 0.5697096418219776
# h4 0.5942494844126724
# Predict -> 0.5723698792858584 Gerçek Değer -> 1
# h3 0.5040439584493673
# h4 0.41898423420213393
# Predict -> 0.29281571245081994 Gerçek Değer -> 0
# h3 0.43981401273298293
# h4 0.31065100035649507
# Predict -> 0.17042283477058146 Gerçek Değer -> 0
# h3 0.5558242793269251
# h4 0.4758978593173652
# Predict -> 0.3784155942300368 Gerçek Değer -> 0

# %%
all_prediction =  [];
for x in X_test:
    if(myNetwork.predict(x) > 0.4):
        all_prediction.append(1)
    else:
        all_prediction.append(0);
# Out:
# h3 0.532016048847171
# h4 0.49979950045953725
# h3 0.436275687440655
# h4 0.26830507321038305
# h3 0.3438176884699896
# h4 0.15069368226245358
# h3 0.46474474999050425
# h4 0.33659216226889704
# h3 0.4167844625155643
# h4 0.23258797815434284
# h3 0.5246508279868637
# h4 0.4181947353538774
# h3 0.35392126452294015
# h4 0.18503409763970086
# h3 0.5859908763693343
# h4 0.5578994701011422
# h3 0.6618601179891581
# h4 0.7455811766879255
# h3 0.4621213163689836
# h4 0.3358531323235935
# h3 0.45837368354871005
# h4 0.3214496121543936
# h3 0.28434003736653346
# h4 0.1271407930161139
# h3 0.6572335930710675
# h4 0.7402385618979976
# h3 0.6416590810087212
# h4 0.727651817437086
# h3 0.46655190838331084
# h4 0.29541110197051895
# h3 0.5361588087621518
# h4 0.4330882717790725
# h3 0.3599555266802485
# h4 0.17581725228547604
# h3 0.40150873791631647
# h4 0.21546302098147585
# h3 0.39940468515046956
# h4 0.25074567953662846
# h3 0.8800520033745483
# h4 0.9140971344727765
# h3 0.6115035471261441
# h4 0.6058653795265827
# h3 0.4418208538580887
# h4 0.31649116782003567
# h3 0.515760419016897
# h4 0.3996870629791015
# h3 0.4099729224013531
# h4 0.24876350198686342
# h3 0.35439057607700225
# h4 0.16837924398722307
# h3 0.47997141897196466
# h4 0.38009742740053054
# h3 0.42272334813128626
# h4 0.2458818721377383
# h3 0.6463561702651696
# h4 0.719586652588476
# h3 0.6955931816421741
# h4 0.7386105002656078
# h3 0.7419401046504899
# h4 0.8347770724893749
# h3 0.44739097120175886
# h4 0.34438067484058493
# h3 0.7648362393572794
# h4 0.8367076104467632
# h3 0.49978390599353517
# h4 0.4133028615640605
# h3 0.43552113379235075
# h4 0.2538997400826517
# h3 0.5696551731751662
# h4 0.5209887306665463
# h3 0.5041670609136778
# h4 0.3728218592685815
# h3 0.5712811486188611
# h4 0.6020854710249373
# h3 0.6842563330114105
# h4 0.7998835029649272
# h3 0.5465021128650085
# h4 0.4827859254477744
# h3 0.5916826825149755
# h4 0.6795715643360541
# h3 0.4749306509341899
# h4 0.33656477713539756
# h3 0.5571732418112542
# h4 0.5823748230423182
# h3 0.566297058774893
# h4 0.43945243035828635
# h3 0.43607033391708155
# h4 0.29275254413979845
# h3 0.6132650028624069
# h4 0.6514872629670291
# h3 0.383913954910702
# h4 0.17676650542151437
# h3 0.5318524977547706
# h4 0.5481265017327573
# h3 0.391087018710646
# h4 0.18819371743859628
# h3 0.6484749912855412
# h4 0.7184471221549874
# h3 0.7049189845032132
# h4 0.8119785165742297
# h3 0.574895109156966
# h4 0.5474254665675807
# h3 0.4695937407633251
# h4 0.41772160381104534
# h3 0.5953661176198298
# h4 0.6431627917667354
# h3 0.5177432916913121
# h4 0.4114399711309791
# h3 0.4723512138182447
# h4 0.3236273434006115
# h3 0.4972634346251932
# h4 0.4335110409937843
# h3 0.548713503554644
# h4 0.49252416168321067
# h3 0.7569742779096965
# h4 0.8800144373504905
# h3 0.6879649311043492
# h4 0.7609755744730184
# h3 0.7101658845733533
# h4 0.8048335494147214
# h3 0.4630632824725767
# h4 0.24392861219569734
# h3 0.5490460550559377
# h4 0.6391540910844282
# h3 0.657276204278168
# h4 0.6503626470092182
# h3 0.6309722358977083
# h4 0.7228143288151309
# h3 0.3677273825821959
# h4 0.18796306861869722
# h3 0.48299026131766587
# h4 0.2644544067870478
# h3 0.4925514922978943
# h4 0.31976345714613114
# h3 0.36611538996137183
# h4 0.1850618217889077
# h3 0.4609570201638088
# h4 0.3355965983993393
# h3 0.525960367061416
# h4 0.44598794920329343
# h3 0.5510002304477909
# h4 0.47816996119644517
# h3 0.495815524664217
# h4 0.34262879904679333
# h3 0.6198526567315308
# h4 0.7046658270463384
# h3 0.4498177487704058
# h4 0.2696405718385663
# h3 0.4990176475793905
# h4 0.40165123047766765
# h3 0.5787320711156515
# h4 0.5531553830652378
# h3 0.4104020761978967
# h4 0.2748622574207681
# h3 0.5604655118889763
# h4 0.5848645523592979
# h3 0.6496945650040397
# h4 0.7071461972008264
# h3 0.490433646501226
# h4 0.42435087529719245
# h3 0.39005049963463334
# h4 0.20524359656074556
# h3 0.3947362314780608
# h4 0.20494185508906893
# h3 0.4028448696451607
# h4 0.3685521232928144
# h3 0.6542915411396868
# h4 0.6916208710312
# h3 0.37209699692882253
# h4 0.21212487526570292
# h3 0.6731172608244339
# h4 0.6471123266313402
# h3 0.5500719505600122
# h4 0.46768478277636066
# h3 0.6287744160373823
# h4 0.661103824710196
# h3 0.36307261502330695
# h4 0.16467318434509903
# h3 0.3734628058379696
# h4 0.1609484050077228
# h3 0.6704845563686741
# h4 0.7622204317196855
# h3 0.41067583764583554
# h4 0.25932388544421664
# h3 0.42541620285325904
# h4 0.2565564571724461
# h3 0.7754205544731929
# h4 0.8614464959201206
# h3 0.5737856491639667
# h4 0.5191033228723981
# h3 0.6698132370041637
# h4 0.7222969116449947
# h3 0.4845213129936442
# h4 0.37551079326048664
# h3 0.6297053146057746
# h4 0.7507947032333324
# h3 0.48613236129769566
# h4 0.33336411136045013
# h3 0.5592906325797314
# h4 0.5717371069017739
# h3 0.4506314196996723
# h4 0.35208475145009516
# h3 0.6223416992968497
# h4 0.6614612950335428
# h3 0.7502539956139933
# h4 0.8084231691740414
# h3 0.6449458291174561
# h4 0.6963621811853605
# h3 0.5560415121106963
# h4 0.5163460784646512
# h3 0.37959511136920715
# h4 0.19802891648455936
# h3 0.5697096418219776
# h4 0.5942494844126724
# h3 0.5040439584493673
# h4 0.41898423420213393
# h3 0.43981401273298293
# h4 0.31065100035649507
# h3 0.5558242793269251
# h4 0.4758978593173652

# %%
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(y_test, all_prediction)
cm.T
# Out:
# array([[54,  9],
#        [22, 25]], dtype=int64)

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, all_prediction));
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      0.71      0.78        76
#            1       0.53      0.74      0.62        34
#
#     accuracy                           0.72       110
#    macro avg       0.69      0.72      0.70       110
# weighted avg       0.76      0.72      0.73       110
